# %%
DATA_DIR = r"D:\Haseeb\Datasets\pacs_data"

# %% [markdown]
# ### Activation_DI

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
import copy
import os
from dataset import get_pacs_dataloaders
from utils import *
from pruning import iterative_pruning

ALL_DOMAINS = ['art_painting', 'cartoon', 'photo', 'sketch']
TARGET_DOMAIN = 'sketch'
SOURCE_DOMAINS = [d for d in ALL_DOMAINS if d != TARGET_DOMAIN]

BATCH_SIZE = 256
NUM_WORKERS = 2
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print("--- Starting Warmup Phase ---")
source_loader_combined, target_loader, class_to_idx = get_pacs_dataloaders(
    data_dir=DATA_DIR, source_domains=SOURCE_DOMAINS, target_domain=TARGET_DOMAIN,
    batch_size=BATCH_SIZE, num_workers=NUM_WORKERS, combine_sources=True
)
num_classes = len(class_to_idx)

model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
model.fc = nn.Linear(model.fc.in_features, num_classes)
model.to(DEVICE)

optimizer = optim.Adam(model.parameters(), lr=1e-4)
WARMUP_EPOCHS = 5
best_warmup_acc = 0.0
WARMUP_MODEL_PATH = "best_warmup_model.pth"

if os.path.exists(WARMUP_MODEL_PATH):
    print("Warmup model already exists. Loading and skipping warmup...")
    model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
    model.fc = nn.Linear(model.fc.in_features, num_classes)
    model.load_state_dict(torch.load(WARMUP_MODEL_PATH, map_location=DEVICE))
    model.to(DEVICE)
else:
    print("No warmup model found. Running warmup training...")
    source_loader_combined, target_loader, class_to_idx = get_pacs_dataloaders(
        data_dir=DATA_DIR, source_domains=SOURCE_DOMAINS, target_domain=TARGET_DOMAIN,
        batch_size=BATCH_SIZE, num_workers=NUM_WORKERS, combine_sources=True
    )

    model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
    model.fc = nn.Linear(model.fc.in_features, num_classes)
    model.to(DEVICE)

    optimizer = optim.Adam(model.parameters(), lr=1e-4)
    WARMUP_EPOCHS = 5

    for epoch in range(WARMUP_EPOCHS):
        train_vanilla(model, source_loader_combined, optimizer, DEVICE, epoch)
        _, val_acc = evaluate(model, target_loader, DEVICE)
        print(f"  Warmup Epoch {epoch+1} Target Accuracy: {val_acc:.2f}%")

        if val_acc > best_warmup_acc:
            best_warmup_acc = val_acc
            torch.save(model.state_dict(), WARMUP_MODEL_PATH)
            print(f"  New best warmup accuracy: {best_warmup_acc:.2f}%. Checkpoint saved.")

    print(f"\nWarmup finished. Best accuracy: {best_warmup_acc:.2f}%")

print("\n--- Starting Iterative Pruning Phase ---")
source_loaders_list, target_loader, _ = get_pacs_dataloaders(
    data_dir=DATA_DIR, source_domains=SOURCE_DOMAINS, target_domain=TARGET_DOMAIN,
    batch_size=BATCH_SIZE, num_workers=NUM_WORKERS, combine_sources=False
)

pruning_model = models.resnet18()
pruning_model.fc = nn.Linear(pruning_model.fc.in_features, num_classes)
pruning_model.load_state_dict(torch.load(WARMUP_MODEL_PATH))
pruning_model.to(DEVICE)

PRUNE_RATES = [0.10, 0.10, 0.10]
FINETUNE_EPOCHS = 5
FINETUNE_LR = 1e-4
ALPHA = 1.0

final_model, final_mask = iterative_pruning(
    model=pruning_model,
    source_loaders_list=source_loaders_list,
    target_loader=target_loader,
    device=DEVICE,
    prune_rates=PRUNE_RATES,
    retrain_epochs=FINETUNE_EPOCHS,
    lr=FINETUNE_LR,
    alpha=ALPHA,
    batch_size=BATCH_SIZE,
    num_workers=NUM_WORKERS,
    SFT=False
)

# --- 4. Final Evaluation ---
print("\n--- Final Evaluation ---")
baseline_acc = best_warmup_acc
apply_mask(final_model, final_mask)
_, final_acc = evaluate(final_model, target_loader, DEVICE, mask=final_mask)

print("\n--- Pruning Summary ---")
print(f"Baseline Target Accuracy (from best warmup): {baseline_acc:.2f}%")
print(f"Final Target Accuracy (from best pruned model): {final_acc:.2f}%")
improvement = final_acc - baseline_acc
print(f"Improvement: {improvement:+.2f}%")
# Out:
# --- Starting Warmup Phase ---
# Creating source datasets for: ['art_painting', 'cartoon', 'photo']
#   - Domain 'art_painting' (ID 0) loaded with 2048 images.
#   - Domain 'cartoon' (ID 1) loaded with 2344 images.
#   - Domain 'photo' (ID 2) loaded with 1670 images.
# Combined source dataloader created with 6062 total images.
# Creating target dataloader for: sketch
#   - Domain 'sketch' loaded with 3929 images.
# No warmup model found. Running warmup training...
# Creating source datasets for: ['art_painting', 'cartoon', 'photo']
#   - Domain 'art_painting' (ID 0) loaded with 2048 images.
#   - Domain 'cartoon' (ID 1) loaded with 2344 images.
#   - Domain 'photo' (ID 2) loaded with 1670 images.
# Combined source dataloader created with 6062 total images.
# Creating target dataloader for: sketch
#   - Domain 'sketch' loaded with 3929 images.
# Epoch 1 Vanilla Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Warmup Epoch 1 Target Accuracy: 63.73%
#   New best warmup accuracy: 63.73%. Checkpoint saved.
# Epoch 2 Vanilla Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Warmup Epoch 2 Target Accuracy: 61.54%
# Epoch 3 Vanilla Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Warmup Epoch 3 Target Accuracy: 63.60%
# Epoch 4 Vanilla Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Warmup Epoch 4 Target Accuracy: 62.66%
# Epoch 5 Vanilla Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Warmup Epoch 5 Target Accuracy: 63.02%
#
# Warmup finished. Best accuracy: 63.73%
#
# --- Starting Iterative Pruning Phase ---
# Creating source datasets for: ['art_painting', 'cartoon', 'photo']
#   - Domain 'art_painting' (ID 0) loaded with 2048 images.
#   - Domain 'cartoon' (ID 1) loaded with 2344 images.
#   - Domain 'photo' (ID 2) loaded with 1670 images.
# Created 3 separate source dataloaders.
# Creating target dataloader for: sketch
#   - Domain 'sketch' loaded with 3929 images.
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
# Initial Baseline Target Accuracy: 63.73%
#
# --- Pruning Iteration 1/3 with base rate 0.1 ---
# Computing filter activations per domain...
#   - Domain 1/3
#   0%|          | 0/8 [00:00<?, ?it/s]
#   - Domain 2/3
#   0%|          | 0/9 [00:00<?, ?it/s]
#   - Domain 3/3
#   0%|          | 0/6 [00:00<?, ?it/s]
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 51/512 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 59.46%
#
# Retraining Epoch 2/5
# Epoch 2 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 65.72%
#
# Retraining Epoch 3/5
# Epoch 3 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 66.00%
#
# Retraining Epoch 4/5
# Epoch 4 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 66.63%
#
# Retraining Epoch 5/5
# Epoch 5 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 65.89%
# Iteration 1 | Best Accuracy in this round: 66.63%
#
# --- Pruning Iteration 2/3 with base rate 0.1 ---
# Computing filter activations per domain...
#   - Domain 1/3
#   0%|          | 0/8 [00:00<?, ?it/s]
#   - Domain 2/3
#   0%|          | 0/9 [00:00<?, ?it/s]
#   - Domain 3/3
#   0%|          | 0/6 [00:00<?, ?it/s]
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 46/461 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 52.97%
#
# Retraining Epoch 2/5
# Epoch 2 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 61.29%
#
# Retraining Epoch 3/5
# Epoch 3 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 60.32%
#
# Retraining Epoch 4/5
# Epoch 4 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 61.54%
#
# Retraining Epoch 5/5
# Epoch 5 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 63.12%
# Iteration 2 | Best Accuracy in this round: 63.12%
#
# --- Pruning Iteration 3/3 with base rate 0.1 ---
# Computing filter activations per domain...
#   - Domain 1/3
#   0%|          | 0/8 [00:00<?, ?it/s]
#   - Domain 2/3
#   0%|          | 0/9 [00:00<?, ?it/s]
#   - Domain 3/3
#   0%|          | 0/6 [00:00<?, ?it/s]
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 41/415 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 62.26%
#
# Retraining Epoch 2/5
# Epoch 2 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 65.05%
#
# Retraining Epoch 3/5
# Epoch 3 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 64.06%
#
# Retraining Epoch 4/5
# Epoch 4 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 64.04%
#
# Retraining Epoch 5/5
# Epoch 5 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 64.34%
# Iteration 3 | Best Accuracy in this round: 65.05%
#
# --- Final Evaluation ---
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
# --- Pruning Summary ---
# Baseline Target Accuracy (from best warmup): 63.73%
# Final Target Accuracy (from best pruned model): 65.05%
# Improvement: +1.32%

# %% [markdown]
# ### Activation_SFT

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
import copy
import os
from dataset import get_pacs_dataloaders
from utils import *
from pruning import iterative_pruning

ALL_DOMAINS = ['art_painting', 'cartoon', 'photo', 'sketch']
TARGET_DOMAIN = 'sketch'
SOURCE_DOMAINS = [d for d in ALL_DOMAINS if d != TARGET_DOMAIN]

BATCH_SIZE = 256
NUM_WORKERS = 2
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print("--- Starting Warmup Phase ---")
source_loader_combined, target_loader, class_to_idx = get_pacs_dataloaders(
    data_dir=DATA_DIR, source_domains=SOURCE_DOMAINS, target_domain=TARGET_DOMAIN,
    batch_size=BATCH_SIZE, num_workers=NUM_WORKERS, combine_sources=True
)
num_classes = len(class_to_idx)

model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
model.fc = nn.Linear(model.fc.in_features, num_classes)
model.to(DEVICE)

optimizer = optim.Adam(model.parameters(), lr=1e-4)
WARMUP_EPOCHS = 5
best_warmup_acc = 0.0
WARMUP_MODEL_PATH = "best_warmup_model.pth"

if os.path.exists(WARMUP_MODEL_PATH):
    print("Warmup model already exists. Loading and skipping warmup...")
    model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
    model.fc = nn.Linear(model.fc.in_features, num_classes)
    model.load_state_dict(torch.load(WARMUP_MODEL_PATH, map_location=DEVICE))
    model.to(DEVICE)
else:
    print("No warmup model found. Running warmup training...")
    source_loader_combined, target_loader, class_to_idx = get_pacs_dataloaders(
        data_dir=DATA_DIR, source_domains=SOURCE_DOMAINS, target_domain=TARGET_DOMAIN,
        batch_size=BATCH_SIZE, num_workers=NUM_WORKERS, combine_sources=True
    )

    model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
    model.fc = nn.Linear(model.fc.in_features, num_classes)
    model.to(DEVICE)

    optimizer = optim.Adam(model.parameters(), lr=1e-4)
    WARMUP_EPOCHS = 5

    for epoch in range(WARMUP_EPOCHS):
        train_vanilla(model, source_loader_combined, optimizer, DEVICE, epoch)
        _, val_acc = evaluate(model, target_loader, DEVICE)
        print(f"  Warmup Epoch {epoch+1} Target Accuracy: {val_acc:.2f}%")

        if val_acc > best_warmup_acc:
            best_warmup_acc = val_acc
            torch.save(model.state_dict(), WARMUP_MODEL_PATH)
            print(f"  New best warmup accuracy: {best_warmup_acc:.2f}%. Checkpoint saved.")

    print(f"\nWarmup finished. Best accuracy: {best_warmup_acc:.2f}%")

print("\n--- Starting Iterative Pruning Phase ---")
source_loaders_list, target_loader, _ = get_pacs_dataloaders(
    data_dir=DATA_DIR, source_domains=SOURCE_DOMAINS, target_domain=TARGET_DOMAIN,
    batch_size=BATCH_SIZE, num_workers=NUM_WORKERS, combine_sources=False
)

pruning_model = models.resnet18()
pruning_model.fc = nn.Linear(pruning_model.fc.in_features, num_classes)
pruning_model.load_state_dict(torch.load(WARMUP_MODEL_PATH))
pruning_model.to(DEVICE)

PRUNE_RATES = [0.10, 0.10, 0.10]
FINETUNE_EPOCHS = 5
FINETUNE_LR = 1e-4
ALPHA = 1.0

final_model, final_mask = iterative_pruning(
    model=pruning_model,
    source_loaders_list=source_loaders_list,
    target_loader=target_loader,
    device=DEVICE,
    prune_rates=PRUNE_RATES,
    retrain_epochs=FINETUNE_EPOCHS,
    lr=FINETUNE_LR,
    alpha=ALPHA,
    batch_size=BATCH_SIZE,
    num_workers=NUM_WORKERS,
    SFT=True
)

# --- 4. Final Evaluation ---
print("\n--- Final Evaluation ---")
baseline_acc = best_warmup_acc
apply_mask(final_model, final_mask)
_, final_acc = evaluate(final_model, target_loader, DEVICE, mask=final_mask)

print("\n--- Pruning Summary ---")
print(f"Baseline Target Accuracy (from best warmup): {baseline_acc:.2f}%")
print(f"Final Target Accuracy (from best pruned model): {final_acc:.2f}%")
improvement = final_acc - baseline_acc
print(f"Improvement: {improvement:+.2f}%")
# Out:
# --- Starting Warmup Phase ---
# Creating source datasets for: ['art_painting', 'cartoon', 'photo']
#   - Domain 'art_painting' (ID 0) loaded with 2048 images.
#   - Domain 'cartoon' (ID 1) loaded with 2344 images.
#   - Domain 'photo' (ID 2) loaded with 1670 images.
# Combined source dataloader created with 6062 total images.
# Creating target dataloader for: sketch
#   - Domain 'sketch' loaded with 3929 images.
# Warmup model already exists. Loading and skipping warmup...
#
# --- Starting Iterative Pruning Phase ---
# Creating source datasets for: ['art_painting', 'cartoon', 'photo']
#   - Domain 'art_painting' (ID 0) loaded with 2048 images.
#   - Domain 'cartoon' (ID 1) loaded with 2344 images.
#   - Domain 'photo' (ID 2) loaded with 1670 images.
# Created 3 separate source dataloaders.
# Creating target dataloader for: sketch
#   - Domain 'sketch' loaded with 3929 images.
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
# Initial Baseline Target Accuracy: 63.73%
#
# --- Pruning Iteration 1/3 with base rate 0.1 ---
# Computing filter activations per domain...
#   - Domain 1/3
#   0%|          | 0/8 [00:00<?, ?it/s]
#   - Domain 2/3
#   0%|          | 0/9 [00:00<?, ?it/s]
#   - Domain 3/3
#   0%|          | 0/6 [00:00<?, ?it/s]
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 51/512 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 57.67%
#
# Retraining Epoch 2/5
# Epoch 2 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 63.04%
#
# Retraining Epoch 3/5
# Epoch 3 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 68.47%
#
# Retraining Epoch 4/5
# Epoch 4 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 66.53%
#
# Retraining Epoch 5/5
# Epoch 5 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 66.73%
# Iteration 1 | Best Accuracy in this round: 68.47%
#
# --- Pruning Iteration 2/3 with base rate 0.1 ---
# Computing filter activations per domain...
#   - Domain 1/3
#   0%|          | 0/8 [00:00<?, ?it/s]
#   - Domain 2/3
#   0%|          | 0/9 [00:00<?, ?it/s]
#   - Domain 3/3
#   0%|          | 0/6 [00:00<?, ?it/s]
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 46/461 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 50.39%
#
# Retraining Epoch 2/5
# Epoch 2 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 63.93%
#
# Retraining Epoch 3/5
# Epoch 3 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 60.14%
#
# Retraining Epoch 4/5
# Epoch 4 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 63.50%
#
# Retraining Epoch 5/5
# Epoch 5 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 63.58%
# Iteration 2 | Best Accuracy in this round: 63.93%
#
# --- Pruning Iteration 3/3 with base rate 0.1 ---
# Computing filter activations per domain...
#   - Domain 1/3
#   0%|          | 0/8 [00:00<?, ?it/s]
#   - Domain 2/3
#   0%|          | 0/9 [00:00<?, ?it/s]
#   - Domain 3/3
#   0%|          | 0/6 [00:00<?, ?it/s]
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 41/415 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 53.98%
#
# Retraining Epoch 2/5
# Epoch 2 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 66.05%
#
# Retraining Epoch 3/5
# Epoch 3 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 65.74%
#
# Retraining Epoch 4/5
# Epoch 4 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 65.23%
#
# Retraining Epoch 5/5
# Epoch 5 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 65.05%
# Iteration 3 | Best Accuracy in this round: 66.05%
#
# --- Final Evaluation ---
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
# --- Pruning Summary ---
# Baseline Target Accuracy (from best warmup): 0.00%
# Final Target Accuracy (from best pruned model): 66.05%
# Improvement: +66.05%

# %% [markdown]
# ### Taylor_SFT

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
import copy
import os
from dataset import get_pacs_dataloaders
from utils import *
from pruning import iterative_pruning

ALL_DOMAINS = ['art_painting', 'cartoon', 'photo', 'sketch']
TARGET_DOMAIN = 'sketch'
SOURCE_DOMAINS = [d for d in ALL_DOMAINS if d != TARGET_DOMAIN]

BATCH_SIZE = 256
NUM_WORKERS = 2
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print("--- Starting Warmup Phase ---")
source_loader_combined, target_loader, class_to_idx = get_pacs_dataloaders(
    data_dir=DATA_DIR, source_domains=SOURCE_DOMAINS, target_domain=TARGET_DOMAIN,
    batch_size=BATCH_SIZE, num_workers=NUM_WORKERS, combine_sources=True
)
num_classes = len(class_to_idx)

model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
model.fc = nn.Linear(model.fc.in_features, num_classes)
model.to(DEVICE)

optimizer = optim.Adam(model.parameters(), lr=1e-4)
WARMUP_EPOCHS = 5
best_warmup_acc = 0.0
WARMUP_MODEL_PATH = "best_warmup_model.pth"

if os.path.exists(WARMUP_MODEL_PATH):
    print("Warmup model already exists. Loading and skipping warmup...")
    model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
    model.fc = nn.Linear(model.fc.in_features, num_classes)
    model.load_state_dict(torch.load(WARMUP_MODEL_PATH, map_location=DEVICE))
    model.to(DEVICE)
else:
    print("No warmup model found. Running warmup training...")
    source_loader_combined, target_loader, class_to_idx = get_pacs_dataloaders(
        data_dir=DATA_DIR, source_domains=SOURCE_DOMAINS, target_domain=TARGET_DOMAIN,
        batch_size=BATCH_SIZE, num_workers=NUM_WORKERS, combine_sources=True
    )

    model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
    model.fc = nn.Linear(model.fc.in_features, num_classes)
    model.to(DEVICE)

    optimizer = optim.Adam(model.parameters(), lr=1e-4)
    WARMUP_EPOCHS = 5

    for epoch in range(WARMUP_EPOCHS):
        train_vanilla(model, source_loader_combined, optimizer, DEVICE, epoch)
        _, val_acc = evaluate(model, target_loader, DEVICE)
        print(f"  Warmup Epoch {epoch+1} Target Accuracy: {val_acc:.2f}%")

        if val_acc > best_warmup_acc:
            best_warmup_acc = val_acc
            torch.save(model.state_dict(), WARMUP_MODEL_PATH)
            print(f"  New best warmup accuracy: {best_warmup_acc:.2f}%. Checkpoint saved.")

    print(f"\nWarmup finished. Best accuracy: {best_warmup_acc:.2f}%")

print("\n--- Starting Iterative Pruning Phase ---")
source_loaders_list, target_loader, _ = get_pacs_dataloaders(
    data_dir=DATA_DIR, source_domains=SOURCE_DOMAINS, target_domain=TARGET_DOMAIN,
    batch_size=BATCH_SIZE, num_workers=NUM_WORKERS, combine_sources=False
)

pruning_model = models.resnet18()
pruning_model.fc = nn.Linear(pruning_model.fc.in_features, num_classes)
pruning_model.load_state_dict(torch.load(WARMUP_MODEL_PATH))
pruning_model.to(DEVICE)

PRUNE_RATES = [0.10, 0.10, 0.10]
FINETUNE_EPOCHS = 5
FINETUNE_LR = 1e-4
ALPHA = 1.0

final_model, final_mask = iterative_pruning(
    model=pruning_model,
    source_loaders_list=source_loaders_list,
    target_loader=target_loader,
    device=DEVICE,
    prune_rates=PRUNE_RATES,
    retrain_epochs=FINETUNE_EPOCHS,
    lr=FINETUNE_LR,
    alpha=ALPHA,
    batch_size=BATCH_SIZE,
    num_workers=NUM_WORKERS,
    SFT=True, 
    importance_type="taylor"
)

# --- 4. Final Evaluation ---
print("\n--- Final Evaluation ---")
baseline_acc = best_warmup_acc
apply_mask(final_model, final_mask)
_, final_acc = evaluate(final_model, target_loader, DEVICE, mask=final_mask)

print("\n--- Pruning Summary ---")
print(f"Baseline Target Accuracy (from best warmup): {baseline_acc:.2f}%")
print(f"Final Target Accuracy (from best pruned model): {final_acc:.2f}%")
improvement = final_acc - baseline_acc
print(f"Improvement: {improvement:+.2f}%")
# Out:
# --- Starting Warmup Phase ---
# Creating source datasets for: ['art_painting', 'cartoon', 'photo']
#   - Domain 'art_painting' (ID 0) loaded with 2048 images.
#   - Domain 'cartoon' (ID 1) loaded with 2344 images.
#   - Domain 'photo' (ID 2) loaded with 1670 images.
# Combined source dataloader created with 6062 total images.
# Creating target dataloader for: sketch
#   - Domain 'sketch' loaded with 3929 images.
# Warmup model already exists. Loading and skipping warmup...
#
# --- Starting Iterative Pruning Phase ---
# Creating source datasets for: ['art_painting', 'cartoon', 'photo']
#   - Domain 'art_painting' (ID 0) loaded with 2048 images.
#   - Domain 'cartoon' (ID 1) loaded with 2344 images.
#   - Domain 'photo' (ID 2) loaded with 1670 images.
# Created 3 separate source dataloaders.
# Creating target dataloader for: sketch
#   - Domain 'sketch' loaded with 3929 images.
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
# Initial Baseline Target Accuracy: 63.73%
#
# --- Pruning Iteration 1/3 with base rate 0.1 ---
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 51/512 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 68.19%
#
# Retraining Epoch 2/5
# Epoch 2 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 63.04%
#
# Retraining Epoch 3/5
# Epoch 3 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 63.53%
#
# Retraining Epoch 4/5
# Epoch 4 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 67.19%
#
# Retraining Epoch 5/5
# Epoch 5 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 66.63%
# Iteration 1 | Best Accuracy in this round: 68.19%
#
# --- Pruning Iteration 2/3 with base rate 0.1 ---
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 46/461 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 63.15%
#
# Retraining Epoch 2/5
# Epoch 2 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 64.95%
#
# Retraining Epoch 3/5
# Epoch 3 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 62.00%
#
# Retraining Epoch 4/5
# Epoch 4 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 61.95%
#
# Retraining Epoch 5/5
# Epoch 5 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 63.45%
# Iteration 2 | Best Accuracy in this round: 64.95%
#
# --- Pruning Iteration 3/3 with base rate 0.1 ---
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 41/415 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 58.82%
#
# Retraining Epoch 2/5
# Epoch 2 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 59.89%
#
# Retraining Epoch 3/5
# Epoch 3 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 65.56%
#
# Retraining Epoch 4/5
# Epoch 4 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 66.15%
#
# Retraining Epoch 5/5
# Epoch 5 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 64.95%
# Iteration 3 | Best Accuracy in this round: 66.15%
#
# --- Final Evaluation ---
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
# --- Pruning Summary ---
# Baseline Target Accuracy (from best warmup): 0.00%
# Final Target Accuracy (from best pruned model): 66.15%
# Improvement: +66.15%

# %% [markdown]
# ### Taylor_DI

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
import copy
import os
from dataset import get_pacs_dataloaders
from utils import *
from pruning import iterative_pruning

ALL_DOMAINS = ['art_painting', 'cartoon', 'photo', 'sketch']
TARGET_DOMAIN = 'sketch'
SOURCE_DOMAINS = [d for d in ALL_DOMAINS if d != TARGET_DOMAIN]

BATCH_SIZE = 256
NUM_WORKERS = 2
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print("--- Starting Warmup Phase ---")
source_loader_combined, target_loader, class_to_idx = get_pacs_dataloaders(
    data_dir=DATA_DIR, source_domains=SOURCE_DOMAINS, target_domain=TARGET_DOMAIN,
    batch_size=BATCH_SIZE, num_workers=NUM_WORKERS, combine_sources=True
)
num_classes = len(class_to_idx)

model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
model.fc = nn.Linear(model.fc.in_features, num_classes)
model.to(DEVICE)

optimizer = optim.Adam(model.parameters(), lr=1e-4)
WARMUP_EPOCHS = 5
best_warmup_acc = 0.0
WARMUP_MODEL_PATH = "best_warmup_model.pth"

if os.path.exists(WARMUP_MODEL_PATH):
    print("Warmup model already exists. Loading and skipping warmup...")
    model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
    model.fc = nn.Linear(model.fc.in_features, num_classes)
    model.load_state_dict(torch.load(WARMUP_MODEL_PATH, map_location=DEVICE))
    model.to(DEVICE)
else:
    print("No warmup model found. Running warmup training...")
    source_loader_combined, target_loader, class_to_idx = get_pacs_dataloaders(
        data_dir=DATA_DIR, source_domains=SOURCE_DOMAINS, target_domain=TARGET_DOMAIN,
        batch_size=BATCH_SIZE, num_workers=NUM_WORKERS, combine_sources=True
    )

    model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
    model.fc = nn.Linear(model.fc.in_features, num_classes)
    model.to(DEVICE)

    optimizer = optim.Adam(model.parameters(), lr=1e-4)
    WARMUP_EPOCHS = 5

    for epoch in range(WARMUP_EPOCHS):
        train_vanilla(model, source_loader_combined, optimizer, DEVICE, epoch)
        _, val_acc = evaluate(model, target_loader, DEVICE)
        print(f"  Warmup Epoch {epoch+1} Target Accuracy: {val_acc:.2f}%")

        if val_acc > best_warmup_acc:
            best_warmup_acc = val_acc
            torch.save(model.state_dict(), WARMUP_MODEL_PATH)
            print(f"  New best warmup accuracy: {best_warmup_acc:.2f}%. Checkpoint saved.")

    print(f"\nWarmup finished. Best accuracy: {best_warmup_acc:.2f}%")

print("\n--- Starting Iterative Pruning Phase ---")
source_loaders_list, target_loader, _ = get_pacs_dataloaders(
    data_dir=DATA_DIR, source_domains=SOURCE_DOMAINS, target_domain=TARGET_DOMAIN,
    batch_size=BATCH_SIZE, num_workers=NUM_WORKERS, combine_sources=False
)

pruning_model = models.resnet18()
pruning_model.fc = nn.Linear(pruning_model.fc.in_features, num_classes)
pruning_model.load_state_dict(torch.load(WARMUP_MODEL_PATH))
pruning_model.to(DEVICE)

PRUNE_RATES = [0.10, 0.10, 0.10]
FINETUNE_EPOCHS = 5
FINETUNE_LR = 1e-4
ALPHA = 1.0

final_model, final_mask = iterative_pruning(
    model=pruning_model,
    source_loaders_list=source_loaders_list,
    target_loader=target_loader,
    device=DEVICE,
    prune_rates=PRUNE_RATES,
    retrain_epochs=FINETUNE_EPOCHS,
    lr=FINETUNE_LR,
    alpha=ALPHA,
    batch_size=BATCH_SIZE,
    num_workers=NUM_WORKERS,
    SFT=False,
    importance_type="taylor")

# --- 4. Final Evaluation ---
print("\n--- Final Evaluation ---")
baseline_acc = best_warmup_acc
apply_mask(final_model, final_mask)
_, final_acc = evaluate(final_model, target_loader, DEVICE, mask=final_mask)

print("\n--- Pruning Summary ---")
print(f"Baseline Target Accuracy (from best warmup): {baseline_acc:.2f}%")
print(f"Final Target Accuracy (from best pruned model): {final_acc:.2f}%")
improvement = final_acc - baseline_acc
print(f"Improvement: {improvement:+.2f}%")
# Out:
# --- Starting Warmup Phase ---
# Creating source datasets for: ['art_painting', 'cartoon', 'photo']
#   - Domain 'art_painting' (ID 0) loaded with 2048 images.
#   - Domain 'cartoon' (ID 1) loaded with 2344 images.
#   - Domain 'photo' (ID 2) loaded with 1670 images.
# Combined source dataloader created with 6062 total images.
# Creating target dataloader for: sketch
#   - Domain 'sketch' loaded with 3929 images.
# Warmup model already exists. Loading and skipping warmup...
#
# --- Starting Iterative Pruning Phase ---
# Creating source datasets for: ['art_painting', 'cartoon', 'photo']
#   - Domain 'art_painting' (ID 0) loaded with 2048 images.
#   - Domain 'cartoon' (ID 1) loaded with 2344 images.
#   - Domain 'photo' (ID 2) loaded with 1670 images.
# Created 3 separate source dataloaders.
# Creating target dataloader for: sketch
#   - Domain 'sketch' loaded with 3929 images.
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
# Initial Baseline Target Accuracy: 63.73%
#
# --- Pruning Iteration 1/3 with base rate 0.1 ---
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 51/512 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 67.40%
#
# Retraining Epoch 2/5
# Epoch 2 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 63.04%
#
# Retraining Epoch 3/5
# Epoch 3 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 63.15%
#
# Retraining Epoch 4/5
# Epoch 4 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 63.37%
#
# Retraining Epoch 5/5
# Epoch 5 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 63.50%
# Iteration 1 | Best Accuracy in this round: 67.40%
#
# --- Pruning Iteration 2/3 with base rate 0.1 ---
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 46/461 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 49.05%
#
# Retraining Epoch 2/5
# Epoch 2 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 60.40%
#
# Retraining Epoch 3/5
# Epoch 3 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 60.52%
#
# Retraining Epoch 4/5
# Epoch 4 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 62.99%
#
# Retraining Epoch 5/5
# Epoch 5 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 62.74%
# Iteration 2 | Best Accuracy in this round: 62.99%
#
# --- Pruning Iteration 3/3 with base rate 0.1 ---
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 41/415 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 66.30%
#
# Retraining Epoch 2/5
# Epoch 2 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 65.84%
#
# Retraining Epoch 3/5
# Epoch 3 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 66.86%
#
# Retraining Epoch 4/5
# Epoch 4 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 66.51%
#
# Retraining Epoch 5/5
# Epoch 5 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 66.30%
# Iteration 3 | Best Accuracy in this round: 66.86%
#
# --- Final Evaluation ---
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
# --- Pruning Summary ---
# Baseline Target Accuracy (from best warmup): 0.00%
# Final Target Accuracy (from best pruned model): 66.86%
# Improvement: +66.86%

# %% [markdown]
# ### MeanVar_DI

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
import copy
import os
from dataset import get_pacs_dataloaders
from utils import *
from pruning import iterative_pruning

ALL_DOMAINS = ['art_painting', 'cartoon', 'photo', 'sketch']
TARGET_DOMAIN = 'sketch'
SOURCE_DOMAINS = [d for d in ALL_DOMAINS if d != TARGET_DOMAIN]

BATCH_SIZE = 256
NUM_WORKERS = 2
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print("--- Starting Warmup Phase ---")
source_loader_combined, target_loader, class_to_idx = get_pacs_dataloaders(
    data_dir=DATA_DIR, source_domains=SOURCE_DOMAINS, target_domain=TARGET_DOMAIN,
    batch_size=BATCH_SIZE, num_workers=NUM_WORKERS, combine_sources=True
)
num_classes = len(class_to_idx)

model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
model.fc = nn.Linear(model.fc.in_features, num_classes)
model.to(DEVICE)

optimizer = optim.Adam(model.parameters(), lr=1e-4)
WARMUP_EPOCHS = 5
best_warmup_acc = 0.0
WARMUP_MODEL_PATH = "best_warmup_model.pth"

if os.path.exists(WARMUP_MODEL_PATH):
    print("Warmup model already exists. Loading and skipping warmup...")
    model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
    model.fc = nn.Linear(model.fc.in_features, num_classes)
    model.load_state_dict(torch.load(WARMUP_MODEL_PATH, map_location=DEVICE))
    model.to(DEVICE)
else:
    print("No warmup model found. Running warmup training...")
    source_loader_combined, target_loader, class_to_idx = get_pacs_dataloaders(
        data_dir=DATA_DIR, source_domains=SOURCE_DOMAINS, target_domain=TARGET_DOMAIN,
        batch_size=BATCH_SIZE, num_workers=NUM_WORKERS, combine_sources=True
    )

    model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
    model.fc = nn.Linear(model.fc.in_features, num_classes)
    model.to(DEVICE)

    optimizer = optim.Adam(model.parameters(), lr=1e-4)
    WARMUP_EPOCHS = 5

    for epoch in range(WARMUP_EPOCHS):
        train_vanilla(model, source_loader_combined, optimizer, DEVICE, epoch)
        _, val_acc = evaluate(model, target_loader, DEVICE)
        print(f"  Warmup Epoch {epoch+1} Target Accuracy: {val_acc:.2f}%")

        if val_acc > best_warmup_acc:
            best_warmup_acc = val_acc
            torch.save(model.state_dict(), WARMUP_MODEL_PATH)
            print(f"  New best warmup accuracy: {best_warmup_acc:.2f}%. Checkpoint saved.")

    print(f"\nWarmup finished. Best accuracy: {best_warmup_acc:.2f}%")

print("\n--- Starting Iterative Pruning Phase ---")
source_loaders_list, target_loader, _ = get_pacs_dataloaders(
    data_dir=DATA_DIR, source_domains=SOURCE_DOMAINS, target_domain=TARGET_DOMAIN,
    batch_size=BATCH_SIZE, num_workers=NUM_WORKERS, combine_sources=False
)

pruning_model = models.resnet18()
pruning_model.fc = nn.Linear(pruning_model.fc.in_features, num_classes)
pruning_model.load_state_dict(torch.load(WARMUP_MODEL_PATH))
pruning_model.to(DEVICE)

PRUNE_RATES = [0.10, 0.10, 0.10]
FINETUNE_EPOCHS = 5
FINETUNE_LR = 1e-4
ALPHA = 1.0

final_model, final_mask = iterative_pruning(
    model=pruning_model,
    source_loaders_list=source_loaders_list,
    target_loader=target_loader,
    device=DEVICE,
    prune_rates=PRUNE_RATES,
    retrain_epochs=FINETUNE_EPOCHS,
    lr=FINETUNE_LR,
    alpha=ALPHA,
    batch_size=BATCH_SIZE,
    num_workers=NUM_WORKERS,
    SFT=False,
    importance_type="meanvar")

# --- 4. Final Evaluation ---
print("\n--- Final Evaluation ---")
baseline_acc = best_warmup_acc
apply_mask(final_model, final_mask)
_, final_acc = evaluate(final_model, target_loader, DEVICE, mask=final_mask)

print("\n--- Pruning Summary ---")
print(f"Baseline Target Accuracy (from best warmup): {baseline_acc:.2f}%")
print(f"Final Target Accuracy (from best pruned model): {final_acc:.2f}%")
improvement = final_acc - baseline_acc
print(f"Improvement: {improvement:+.2f}%")
# Out:
# --- Starting Warmup Phase ---
# Creating source datasets for: ['art_painting', 'cartoon', 'photo']
#   - Domain 'art_painting' (ID 0) loaded with 2048 images.
#   - Domain 'cartoon' (ID 1) loaded with 2344 images.
#   - Domain 'photo' (ID 2) loaded with 1670 images.
# Combined source dataloader created with 6062 total images.
# Creating target dataloader for: sketch
#   - Domain 'sketch' loaded with 3929 images.
# Warmup model already exists. Loading and skipping warmup...
#
# --- Starting Iterative Pruning Phase ---
# Creating source datasets for: ['art_painting', 'cartoon', 'photo']
#   - Domain 'art_painting' (ID 0) loaded with 2048 images.
#   - Domain 'cartoon' (ID 1) loaded with 2344 images.
#   - Domain 'photo' (ID 2) loaded with 1670 images.
# Created 3 separate source dataloaders.
# Creating target dataloader for: sketch
#   - Domain 'sketch' loaded with 3929 images.
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
# Initial Baseline Target Accuracy: 63.73%
#
# --- Pruning Iteration 1/3 with base rate 0.1 ---
# Computing mean/variance importance...
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 51/512 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 62.20%
#
# Retraining Epoch 2/5
# Epoch 2 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 60.93%
#
# Retraining Epoch 3/5
# Epoch 3 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 62.92%
#
# Retraining Epoch 4/5
# Epoch 4 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 63.43%
#
# Retraining Epoch 5/5
# Epoch 5 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 64.09%
# Iteration 1 | Best Accuracy in this round: 64.09%
#
# --- Pruning Iteration 2/3 with base rate 0.1 ---
# Computing mean/variance importance...
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 46/461 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 50.80%
#
# Retraining Epoch 2/5
# Epoch 2 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 57.90%
#
# Retraining Epoch 3/5
# Epoch 3 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 61.67%
#
# Retraining Epoch 4/5
# Epoch 4 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 61.26%
#
# Retraining Epoch 5/5
# Epoch 5 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 61.01%
# Iteration 2 | Best Accuracy in this round: 61.67%
#
# --- Pruning Iteration 3/3 with base rate 0.1 ---
# Computing mean/variance importance...
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 41/415 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 62.03%
#
# Retraining Epoch 2/5
# Epoch 2 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 58.82%
#
# Retraining Epoch 3/5
# Epoch 3 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 60.32%
#
# Retraining Epoch 4/5
# Epoch 4 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 59.68%
#
# Retraining Epoch 5/5
# Epoch 5 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 60.75%
# Iteration 3 | Best Accuracy in this round: 62.03%
#
# --- Final Evaluation ---
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
# --- Pruning Summary ---
# Baseline Target Accuracy (from best warmup): 0.00%
# Final Target Accuracy (from best pruned model): 62.03%
# Improvement: +62.03%

# %% [markdown]
# ### MeanVar_SFT

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
import copy
import os
from dataset import get_pacs_dataloaders
from utils import *
from pruning import iterative_pruning

ALL_DOMAINS = ['art_painting', 'cartoon', 'photo', 'sketch']
TARGET_DOMAIN = 'sketch'
SOURCE_DOMAINS = [d for d in ALL_DOMAINS if d != TARGET_DOMAIN]

BATCH_SIZE = 256
NUM_WORKERS = 2
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print("--- Starting Warmup Phase ---")
source_loader_combined, target_loader, class_to_idx = get_pacs_dataloaders(
    data_dir=DATA_DIR, source_domains=SOURCE_DOMAINS, target_domain=TARGET_DOMAIN,
    batch_size=BATCH_SIZE, num_workers=NUM_WORKERS, combine_sources=True
)
num_classes = len(class_to_idx)

model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
model.fc = nn.Linear(model.fc.in_features, num_classes)
model.to(DEVICE)

optimizer = optim.Adam(model.parameters(), lr=1e-4)
WARMUP_EPOCHS = 5
best_warmup_acc = 0.0
WARMUP_MODEL_PATH = "best_warmup_model.pth"

if os.path.exists(WARMUP_MODEL_PATH):
    print("Warmup model already exists. Loading and skipping warmup...")
    model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
    model.fc = nn.Linear(model.fc.in_features, num_classes)
    model.load_state_dict(torch.load(WARMUP_MODEL_PATH, map_location=DEVICE))
    model.to(DEVICE)
else:
    print("No warmup model found. Running warmup training...")
    source_loader_combined, target_loader, class_to_idx = get_pacs_dataloaders(
        data_dir=DATA_DIR, source_domains=SOURCE_DOMAINS, target_domain=TARGET_DOMAIN,
        batch_size=BATCH_SIZE, num_workers=NUM_WORKERS, combine_sources=True
    )

    model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
    model.fc = nn.Linear(model.fc.in_features, num_classes)
    model.to(DEVICE)

    optimizer = optim.Adam(model.parameters(), lr=1e-4)
    WARMUP_EPOCHS = 5

    for epoch in range(WARMUP_EPOCHS):
        train_vanilla(model, source_loader_combined, optimizer, DEVICE, epoch)
        _, val_acc = evaluate(model, target_loader, DEVICE)
        print(f"  Warmup Epoch {epoch+1} Target Accuracy: {val_acc:.2f}%")

        if val_acc > best_warmup_acc:
            best_warmup_acc = val_acc
            torch.save(model.state_dict(), WARMUP_MODEL_PATH)
            print(f"  New best warmup accuracy: {best_warmup_acc:.2f}%. Checkpoint saved.")

    print(f"\nWarmup finished. Best accuracy: {best_warmup_acc:.2f}%")

print("\n--- Starting Iterative Pruning Phase ---")
source_loaders_list, target_loader, _ = get_pacs_dataloaders(
    data_dir=DATA_DIR, source_domains=SOURCE_DOMAINS, target_domain=TARGET_DOMAIN,
    batch_size=BATCH_SIZE, num_workers=NUM_WORKERS, combine_sources=False
)

pruning_model = models.resnet18()
pruning_model.fc = nn.Linear(pruning_model.fc.in_features, num_classes)
pruning_model.load_state_dict(torch.load(WARMUP_MODEL_PATH))
pruning_model.to(DEVICE)

PRUNE_RATES = [0.10, 0.10, 0.10]
FINETUNE_EPOCHS = 5
FINETUNE_LR = 1e-4
ALPHA = 1.0

final_model, final_mask = iterative_pruning(
    model=pruning_model,
    source_loaders_list=source_loaders_list,
    target_loader=target_loader,
    device=DEVICE,
    prune_rates=PRUNE_RATES,
    retrain_epochs=FINETUNE_EPOCHS,
    lr=FINETUNE_LR,
    alpha=ALPHA,
    batch_size=BATCH_SIZE,
    num_workers=NUM_WORKERS,
    SFT=False,
    importance_type="meanvar")

# --- 4. Final Evaluation ---
print("\n--- Final Evaluation ---")
baseline_acc = best_warmup_acc
apply_mask(final_model, final_mask)
_, final_acc = evaluate(final_model, target_loader, DEVICE, mask=final_mask)

print("\n--- Pruning Summary ---")
print(f"Baseline Target Accuracy (from best warmup): {baseline_acc:.2f}%")
print(f"Final Target Accuracy (from best pruned model): {final_acc:.2f}%")
improvement = final_acc - baseline_acc
print(f"Improvement: {improvement:+.2f}%")
# Out:
# --- Starting Warmup Phase ---
# Creating source datasets for: ['art_painting', 'cartoon', 'photo']
#   - Domain 'art_painting' (ID 0) loaded with 2048 images.
#   - Domain 'cartoon' (ID 1) loaded with 2344 images.
#   - Domain 'photo' (ID 2) loaded with 1670 images.
# Combined source dataloader created with 6062 total images.
# Creating target dataloader for: sketch
#   - Domain 'sketch' loaded with 3929 images.
# Warmup model already exists. Loading and skipping warmup...
#
# --- Starting Iterative Pruning Phase ---
# Creating source datasets for: ['art_painting', 'cartoon', 'photo']
#   - Domain 'art_painting' (ID 0) loaded with 2048 images.
#   - Domain 'cartoon' (ID 1) loaded with 2344 images.
#   - Domain 'photo' (ID 2) loaded with 1670 images.
# Created 3 separate source dataloaders.
# Creating target dataloader for: sketch
#   - Domain 'sketch' loaded with 3929 images.
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
# Initial Baseline Target Accuracy: 63.73%
#
# --- Pruning Iteration 1/3 with base rate 0.1 ---
# Computing mean/variance importance...
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 51/512 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 64.95%
#
# Retraining Epoch 2/5
# Epoch 2 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 64.27%
#
# Retraining Epoch 3/5
# Epoch 3 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 62.64%
#
# Retraining Epoch 4/5
# Epoch 4 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 63.37%
#
# Retraining Epoch 5/5
# Epoch 5 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 64.47%
# Iteration 1 | Best Accuracy in this round: 64.95%
#
# --- Pruning Iteration 2/3 with base rate 0.1 ---
# Computing mean/variance importance...
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 46/461 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 57.50%
#
# Retraining Epoch 2/5
# Epoch 2 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 61.82%
#
# Retraining Epoch 3/5
# Epoch 3 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 61.95%
#
# Retraining Epoch 4/5
# Epoch 4 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 62.51%
#
# Retraining Epoch 5/5
# Epoch 5 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 63.12%
# Iteration 2 | Best Accuracy in this round: 63.12%
#
# --- Pruning Iteration 3/3 with base rate 0.1 ---
# Computing mean/variance importance...
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 41/415 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 59.02%
#
# Retraining Epoch 2/5
# Epoch 2 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 56.32%
#
# Retraining Epoch 3/5
# Epoch 3 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 62.15%
#
# Retraining Epoch 4/5
# Epoch 4 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 60.80%
#
# Retraining Epoch 5/5
# Epoch 5 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 60.47%
# Iteration 3 | Best Accuracy in this round: 62.15%
#
# --- Final Evaluation ---
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
# --- Pruning Summary ---
# Baseline Target Accuracy (from best warmup): 0.00%
# Final Target Accuracy (from best pruned model): 62.15%
# Improvement: +62.15%

# %%
import os
import csv
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models

from dataset import get_pacs_dataloaders
from utils import *
from pruning import iterative_pruning

ALL_DOMAINS = ['art_painting', 'cartoon', 'photo', 'sketch']
BATCH_SIZE = 256
NUM_WORKERS = 2
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

PRUNE_RATES = [0.10, 0.10, 0.10]
FINETUNE_EPOCHS = 5
FINETUNE_LR = 1e-4
ALPHA = 1.0


# CSV output
CSV_PATH = "pacs_pruning_results.csv"
CSV_FIELDS = [
    "target_domain",
    "warmup_model",
    "pruned_model",
    "mask_file",
    "best_warmup_acc",
    "final_pruned_acc",
    "improvement",
    "percent_pruned"   # percent of parameters removed (sparsity)
]


def ensure_csv_header(path, fields):
    if not os.path.exists(path):
        with open(path, "w", newline="") as f:
            writer = csv.DictWriter(f, fieldnames=fields)
            writer.writeheader()


def append_result_to_csv(path, row, fields):
    with open(path, "a", newline="") as f:
        writer = csv.DictWriter(f, fieldnames=fields)
        writer.writerow(row)


def compute_percent_pruned(mask):
    """
    Given `mask` (assumed to be a state-dict-like mapping of tensors with 0/1),
    compute percentage of parameters that are zero (pruned).
    """
    total = 0
    zeros = 0
    for k, v in mask.items():
        if not isinstance(v, torch.Tensor):
            try:
                v = torch.tensor(v)
            except Exception:
                continue
        total += v.numel()
        zeros += int((v == 0).sum().item())
    if total == 0:
        return 0.0
    percent_pruned = 100.0 * zeros / total
    return percent_pruned


def run_for_target_domain(TARGET_DOMAIN):
    print("\n" + "=" * 70)
    print(f"RUNNING PIPELINE FOR TARGET DOMAIN: {TARGET_DOMAIN}")
    print("=" * 70 + "\n")

    SOURCE_DOMAINS = [d for d in ALL_DOMAINS if d != TARGET_DOMAIN]
    WARMUP_MODEL_PATH = f"warmup_{TARGET_DOMAIN}.pth"
    PRUNED_MODEL_PATH = f"pruned_{TARGET_DOMAIN}.pth"
    PRUNED_MASK_PATH = f"mask_{TARGET_DOMAIN}.pth"

    # ---------- DATALOADERS ----------
    source_loader_combined, target_loader, class_to_idx = get_pacs_dataloaders(
        data_dir=DATA_DIR,
        source_domains=SOURCE_DOMAINS,
        target_domain=TARGET_DOMAIN,
        batch_size=BATCH_SIZE,
        num_workers=NUM_WORKERS,
        combine_sources=True
    )
    num_classes = len(class_to_idx)

    # ---------- WARMUP ----------
    best_warmup_acc = 0.0
    if os.path.exists(WARMUP_MODEL_PATH):
        print(f"Found existing warmup checkpoint: {WARMUP_MODEL_PATH}. Loading.")
        model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
        model.fc = nn.Linear(model.fc.in_features, num_classes)
        model.load_state_dict(torch.load(WARMUP_MODEL_PATH, map_location=DEVICE))
        model.to(DEVICE)
        # optional: evaluate loaded model to populate best_warmup_acc
        _, best_warmup_acc = evaluate(model, target_loader, DEVICE)
        print(f"  Warmup loaded eval -> {best_warmup_acc:.2f}%")
    else:
        print("No warmup checkpoint found. Running warmup training.")
        model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
        model.fc = nn.Linear(model.fc.in_features, num_classes)
        model.to(DEVICE)
        optimizer = optim.Adam(model.parameters(), lr=1e-4)
        WARMUP_EPOCHS = 5
        for epoch in range(WARMUP_EPOCHS):
            train_vanilla(model, source_loader_combined, optimizer, DEVICE, epoch)
            _, val_acc = evaluate(model, target_loader, DEVICE)
            print(f"  Warmup Epoch {epoch+1}: Target Accuracy = {val_acc:.2f}%")
            if val_acc > best_warmup_acc:
                best_warmup_acc = val_acc
                torch.save(model.state_dict(), WARMUP_MODEL_PATH)
                print(f"    Saved new best warmup ({best_warmup_acc:.2f}%).")

    # ---------- PRUNING ----------
    print("\nStarting iterative pruning...")
    source_loaders_list, target_loader, _ = get_pacs_dataloaders(
        data_dir=DATA_DIR,
        source_domains=SOURCE_DOMAINS,
        target_domain=TARGET_DOMAIN,
        batch_size=BATCH_SIZE,
        num_workers=NUM_WORKERS,
        combine_sources=False
    )

    pruning_model = models.resnet18()
    pruning_model.fc = nn.Linear(pruning_model.fc.in_features, num_classes)
    pruning_model.load_state_dict(torch.load(WARMUP_MODEL_PATH, map_location=DEVICE))
    pruning_model.to(DEVICE)

    final_model, final_mask = iterative_pruning(
        model=pruning_model,
        source_loaders_list=source_loaders_list,
        target_loader=target_loader,
        device=DEVICE,
        prune_rates=PRUNE_RATES,
        retrain_epochs=FINETUNE_EPOCHS,
        lr=FINETUNE_LR,
        alpha=ALPHA,
        batch_size=BATCH_SIZE,
        num_workers=NUM_WORKERS,
        SFT=False,
        importance_type="taylor"
    )

    # ---------- FINAL EVAL ----------
    apply_mask(final_model, final_mask)
    _, final_acc = evaluate(final_model, target_loader, DEVICE, mask=final_mask)
    percent_pruned = compute_percent_pruned(final_mask)

    print("\n--- Summary for", TARGET_DOMAIN, "---")
    print(f"Warmup best acc: {best_warmup_acc:.2f}%")
    print(f"Final pruned acc: {final_acc:.2f}%")
    print(f"Improvement: {final_acc - best_warmup_acc:+.2f}%")
    print(f"Percent pruned (zeros in mask): {percent_pruned:.2f}%")

    # Save artifacts
    torch.save(final_model.state_dict(), PRUNED_MODEL_PATH)
    torch.save(final_mask, PRUNED_MASK_PATH)

    # Append result row to CSV
    row = {
        "target_domain": TARGET_DOMAIN,
        "warmup_model": os.path.abspath(WARMUP_MODEL_PATH),
        "pruned_model": os.path.abspath(PRUNED_MODEL_PATH),
        "mask_file": os.path.abspath(PRUNED_MASK_PATH),
        "best_warmup_acc": f"{best_warmup_acc:.4f}",
        "final_pruned_acc": f"{final_acc:.4f}",
        "improvement": f"{(final_acc - best_warmup_acc):.4f}",
        "percent_pruned": f"{percent_pruned:.4f}"
    }
    append_result_to_csv(CSV_PATH, row, CSV_FIELDS)
    print(f"Results appended to {CSV_PATH}")

    return row


if __name__ == "__main__":
    ensure_csv_header(CSV_PATH, CSV_FIELDS)

    all_results = []
    for domain in ALL_DOMAINS:
        try:
            res = run_for_target_domain(domain)
            all_results.append(res)
        except Exception as e:
            print(f"ERROR while processing {domain}: {e}")
            # continue with next domain
            continue

    # Print final table (simple)
    print("\nALL RUNS COMPLETE. Summary rows:")
    for r in all_results:
        print(r)
    print(f"\nCSV saved at: {os.path.abspath(CSV_PATH)}")
# Out:
# ======================================================================
# RUNNING PIPELINE FOR TARGET DOMAIN: art_painting
# ======================================================================
#
# Creating source datasets for: ['cartoon', 'photo', 'sketch']
#   - Domain 'cartoon' (ID 0) loaded with 2344 images.
#   - Domain 'photo' (ID 1) loaded with 1670 images.
#   - Domain 'sketch' (ID 2) loaded with 3929 images.
# Combined source dataloader created with 7943 total images.
# Creating target dataloader for: art_painting
#   - Domain 'art_painting' loaded with 2048 images.
# No warmup checkpoint found. Running warmup training.
# Epoch 1 Vanilla Training:   0%|          | 0/31 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Warmup Epoch 1: Target Accuracy = 69.53%
#     Saved new best warmup (69.53%).
# Epoch 2 Vanilla Training:   0%|          | 0/31 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Warmup Epoch 2: Target Accuracy = 72.95%
#     Saved new best warmup (72.95%).
# Epoch 3 Vanilla Training:   0%|          | 0/31 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Warmup Epoch 3: Target Accuracy = 70.80%
# Epoch 4 Vanilla Training:   0%|          | 0/31 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Warmup Epoch 4: Target Accuracy = 73.39%
#     Saved new best warmup (73.39%).
# Epoch 5 Vanilla Training:   0%|          | 0/31 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Warmup Epoch 5: Target Accuracy = 74.37%
#     Saved new best warmup (74.37%).
#
# Starting iterative pruning...
# Creating source datasets for: ['cartoon', 'photo', 'sketch']
#   - Domain 'cartoon' (ID 0) loaded with 2344 images.
#   - Domain 'photo' (ID 1) loaded with 1670 images.
#   - Domain 'sketch' (ID 2) loaded with 3929 images.
# Created 3 separate source dataloaders.
# Creating target dataloader for: art_painting
#   - Domain 'art_painting' loaded with 2048 images.
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
# Initial Baseline Target Accuracy: 74.37%
#
# --- Pruning Iteration 1/3 with base rate 0.1 ---
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 51/512 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Training:   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 69.29%
#
# Retraining Epoch 2/5
# Epoch 2 Training:   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 69.29%
#
# Retraining Epoch 3/5
# Epoch 3 Training:   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 70.12%
#
# Retraining Epoch 4/5
# Epoch 4 Training:   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 69.53%
#
# Retraining Epoch 5/5
# Epoch 5 Training:   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 70.36%
# Iteration 1 | Best Accuracy in this round: 70.36%
#
# --- Pruning Iteration 2/3 with base rate 0.1 ---
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 46/461 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Training:   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 65.87%
#
# Retraining Epoch 2/5
# Epoch 2 Training:   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 70.80%
#
# Retraining Epoch 3/5
# Epoch 3 Training:   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 67.09%
#
# Retraining Epoch 4/5
# Epoch 4 Training:   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 71.68%
#
# Retraining Epoch 5/5
# Epoch 5 Training:   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 70.21%
# Iteration 2 | Best Accuracy in this round: 71.68%
#
# --- Pruning Iteration 3/3 with base rate 0.1 ---
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 41/415 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Training:   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 63.33%
#
# Retraining Epoch 2/5
# Epoch 2 Training:   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 64.11%
#
# Retraining Epoch 3/5
# Epoch 3 Training:   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 64.36%
#
# Retraining Epoch 4/5
# Epoch 4 Training:   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 65.53%
#
# Retraining Epoch 5/5
# Epoch 5 Training:   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 65.92%
# Iteration 3 | Best Accuracy in this round: 65.92%
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
# --- Summary for art_painting ---
# Warmup best acc: 74.37%
# Final pruned acc: 65.92%
# Improvement: -8.45%
# Percent pruned (zeros in mask): 25.93%
# Results appended to pacs_pruning_results.csv
#
# ======================================================================
# RUNNING PIPELINE FOR TARGET DOMAIN: cartoon
# ======================================================================
#
# Creating source datasets for: ['art_painting', 'photo', 'sketch']
#   - Domain 'art_painting' (ID 0) loaded with 2048 images.
#   - Domain 'photo' (ID 1) loaded with 1670 images.
#   - Domain 'sketch' (ID 2) loaded with 3929 images.
# Combined source dataloader created with 7647 total images.
# Creating target dataloader for: cartoon
#   - Domain 'cartoon' loaded with 2344 images.
# No warmup checkpoint found. Running warmup training.
# Epoch 1 Vanilla Training:   0%|          | 0/29 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Warmup Epoch 1: Target Accuracy = 64.59%
#     Saved new best warmup (64.59%).
# Epoch 2 Vanilla Training:   0%|          | 0/29 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Warmup Epoch 2: Target Accuracy = 69.45%
#     Saved new best warmup (69.45%).
# Epoch 3 Vanilla Training:   0%|          | 0/29 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Warmup Epoch 3: Target Accuracy = 72.06%
#     Saved new best warmup (72.06%).
# Epoch 4 Vanilla Training:   0%|          | 0/29 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Warmup Epoch 4: Target Accuracy = 73.17%
#     Saved new best warmup (73.17%).
# Epoch 5 Vanilla Training:   0%|          | 0/29 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Warmup Epoch 5: Target Accuracy = 71.16%
#
# Starting iterative pruning...
# Creating source datasets for: ['art_painting', 'photo', 'sketch']
#   - Domain 'art_painting' (ID 0) loaded with 2048 images.
#   - Domain 'photo' (ID 1) loaded with 1670 images.
#   - Domain 'sketch' (ID 2) loaded with 3929 images.
# Created 3 separate source dataloaders.
# Creating target dataloader for: cartoon
#   - Domain 'cartoon' loaded with 2344 images.
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
# Initial Baseline Target Accuracy: 73.17%
#
# --- Pruning Iteration 1/3 with base rate 0.1 ---
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 51/512 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 65.49%
#
# Retraining Epoch 2/5
# Epoch 2 Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 67.88%
#
# Retraining Epoch 3/5
# Epoch 3 Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 71.89%
#
# Retraining Epoch 4/5
# Epoch 4 Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 67.75%
#
# Retraining Epoch 5/5
# Epoch 5 Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 69.41%
# Iteration 1 | Best Accuracy in this round: 71.89%
#
# --- Pruning Iteration 2/3 with base rate 0.1 ---
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 46/461 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 67.83%
#
# Retraining Epoch 2/5
# Epoch 2 Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 71.59%
#
# Retraining Epoch 3/5
# Epoch 3 Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 67.70%
#
# Retraining Epoch 4/5
# Epoch 4 Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 73.08%
#
# Retraining Epoch 5/5
# Epoch 5 Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 72.27%
# Iteration 2 | Best Accuracy in this round: 73.08%
#
# --- Pruning Iteration 3/3 with base rate 0.1 ---
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 41/415 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 66.08%
#
# Retraining Epoch 2/5
# Epoch 2 Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 68.17%
#
# Retraining Epoch 3/5
# Epoch 3 Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 69.16%
#
# Retraining Epoch 4/5
# Epoch 4 Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 69.54%
#
# Retraining Epoch 5/5
# Epoch 5 Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 69.58%
# Iteration 3 | Best Accuracy in this round: 69.58%
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
# --- Summary for cartoon ---
# Warmup best acc: 73.17%
# Final pruned acc: 69.58%
# Improvement: -3.58%
# Percent pruned (zeros in mask): 25.93%
# Results appended to pacs_pruning_results.csv
#
# ======================================================================
# RUNNING PIPELINE FOR TARGET DOMAIN: photo
# ======================================================================
#
# Creating source datasets for: ['art_painting', 'cartoon', 'sketch']
#   - Domain 'art_painting' (ID 0) loaded with 2048 images.
#   - Domain 'cartoon' (ID 1) loaded with 2344 images.
#   - Domain 'sketch' (ID 2) loaded with 3929 images.
# Combined source dataloader created with 8321 total images.
# Creating target dataloader for: photo
#   - Domain 'photo' loaded with 1670 images.
# No warmup checkpoint found. Running warmup training.
# Epoch 1 Vanilla Training:   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Warmup Epoch 1: Target Accuracy = 92.10%
#     Saved new best warmup (92.10%).
# Epoch 2 Vanilla Training:   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Warmup Epoch 2: Target Accuracy = 92.57%
#     Saved new best warmup (92.57%).
# Epoch 3 Vanilla Training:   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Warmup Epoch 3: Target Accuracy = 93.95%
#     Saved new best warmup (93.95%).
# Epoch 4 Vanilla Training:   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Warmup Epoch 4: Target Accuracy = 92.93%
# Epoch 5 Vanilla Training:   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Warmup Epoch 5: Target Accuracy = 94.01%
#     Saved new best warmup (94.01%).
#
# Starting iterative pruning...
# Creating source datasets for: ['art_painting', 'cartoon', 'sketch']
#   - Domain 'art_painting' (ID 0) loaded with 2048 images.
#   - Domain 'cartoon' (ID 1) loaded with 2344 images.
#   - Domain 'sketch' (ID 2) loaded with 3929 images.
# Created 3 separate source dataloaders.
# Creating target dataloader for: photo
#   - Domain 'photo' loaded with 1670 images.
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
# Initial Baseline Target Accuracy: 94.01%
#
# --- Pruning Iteration 1/3 with base rate 0.1 ---
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 51/512 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Training:   0%|          | 0/33 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 92.99%
#
# Retraining Epoch 2/5
# Epoch 2 Training:   0%|          | 0/33 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 92.99%
#
# Retraining Epoch 3/5
# Epoch 3 Training:   0%|          | 0/33 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 94.43%
#
# Retraining Epoch 4/5
# Epoch 4 Training:   0%|          | 0/33 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 94.55%
#
# Retraining Epoch 5/5
# Epoch 5 Training:   0%|          | 0/33 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 94.55%
# Iteration 1 | Best Accuracy in this round: 94.55%
#
# --- Pruning Iteration 2/3 with base rate 0.1 ---
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 46/461 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Training:   0%|          | 0/33 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 92.40%
#
# Retraining Epoch 2/5
# Epoch 2 Training:   0%|          | 0/33 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 88.26%
#
# Retraining Epoch 3/5
# Epoch 3 Training:   0%|          | 0/33 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 92.40%
#
# Retraining Epoch 4/5
# Epoch 4 Training:   0%|          | 0/33 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 93.11%
#
# Retraining Epoch 5/5
# Epoch 5 Training:   0%|          | 0/33 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 93.65%
# Iteration 2 | Best Accuracy in this round: 93.65%
#
# --- Pruning Iteration 3/3 with base rate 0.1 ---
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 41/415 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Training:   0%|          | 0/33 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 92.51%
#
# Retraining Epoch 2/5
# Epoch 2 Training:   0%|          | 0/33 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 92.87%
#
# Retraining Epoch 3/5
# Epoch 3 Training:   0%|          | 0/33 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 92.81%
#
# Retraining Epoch 4/5
# Epoch 4 Training:   0%|          | 0/33 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 92.81%
#
# Retraining Epoch 5/5
# Epoch 5 Training:   0%|          | 0/33 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 92.75%
# Iteration 3 | Best Accuracy in this round: 92.87%
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
# --- Summary for photo ---
# Warmup best acc: 94.01%
# Final pruned acc: 92.87%
# Improvement: -1.14%
# Percent pruned (zeros in mask): 25.93%
# Results appended to pacs_pruning_results.csv
#
# ======================================================================
# RUNNING PIPELINE FOR TARGET DOMAIN: sketch
# ======================================================================
#
# Creating source datasets for: ['art_painting', 'cartoon', 'photo']
#   - Domain 'art_painting' (ID 0) loaded with 2048 images.
#   - Domain 'cartoon' (ID 1) loaded with 2344 images.
#   - Domain 'photo' (ID 2) loaded with 1670 images.
# Combined source dataloader created with 6062 total images.
# Creating target dataloader for: sketch
#   - Domain 'sketch' loaded with 3929 images.
# No warmup checkpoint found. Running warmup training.
# Epoch 1 Vanilla Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Warmup Epoch 1: Target Accuracy = 64.95%
#     Saved new best warmup (64.95%).
# Epoch 2 Vanilla Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Warmup Epoch 2: Target Accuracy = 57.29%
# Epoch 3 Vanilla Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Warmup Epoch 3: Target Accuracy = 60.83%
# Epoch 4 Vanilla Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Warmup Epoch 4: Target Accuracy = 60.58%
# Epoch 5 Vanilla Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Warmup Epoch 5: Target Accuracy = 63.71%
#
# Starting iterative pruning...
# Creating source datasets for: ['art_painting', 'cartoon', 'photo']
#   - Domain 'art_painting' (ID 0) loaded with 2048 images.
#   - Domain 'cartoon' (ID 1) loaded with 2344 images.
#   - Domain 'photo' (ID 2) loaded with 1670 images.
# Created 3 separate source dataloaders.
# Creating target dataloader for: sketch
#   - Domain 'sketch' loaded with 3929 images.
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
# Initial Baseline Target Accuracy: 64.95%
#
# --- Pruning Iteration 1/3 with base rate 0.1 ---
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 51/512 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 54.59%
#
# Retraining Epoch 2/5
# Epoch 2 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 61.19%
#
# Retraining Epoch 3/5
# Epoch 3 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 64.90%
#
# Retraining Epoch 4/5
# Epoch 4 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 63.91%
#
# Retraining Epoch 5/5
# Epoch 5 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 64.77%
# Iteration 1 | Best Accuracy in this round: 64.90%
#
# --- Pruning Iteration 2/3 with base rate 0.1 ---
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 46/461 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 62.00%
#
# Retraining Epoch 2/5
# Epoch 2 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 61.82%
#
# Retraining Epoch 3/5
# Epoch 3 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 61.31%
#
# Retraining Epoch 4/5
# Epoch 4 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 63.17%
#
# Retraining Epoch 5/5
# Epoch 5 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 63.76%
# Iteration 2 | Best Accuracy in this round: 63.76%
#
# --- Pruning Iteration 3/3 with base rate 0.1 ---
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 41/415 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 59.99%
#
# Retraining Epoch 2/5
# Epoch 2 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 63.76%
#
# Retraining Epoch 3/5
# Epoch 3 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 67.80%
#
# Retraining Epoch 4/5
# Epoch 4 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 67.01%
#
# Retraining Epoch 5/5
# Epoch 5 Training:   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 66.96%
# Iteration 3 | Best Accuracy in this round: 67.80%
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
# --- Summary for sketch ---
# Warmup best acc: 64.95%
# Final pruned acc: 67.80%
# Improvement: +2.85%
# Percent pruned (zeros in mask): 25.93%
# Results appended to pacs_pruning_results.csv
#
# ALL RUNS COMPLETE. Summary rows:
# {'target_domain': 'art_painting', 'warmup_model': 'd:\\Haseeb\\pruning_sproj\\warmup_art_painting.pth', 'pruned_model': 'd:\\Haseeb\\pruning_sproj\\pruned_art_painting.pth', 'mask_file': 'd:\\Haseeb\\pruning_sproj\\mask_art_painting.pth', 'best_warmup_acc': '74.3652', 'final_pruned_acc': '65.9180', 'improvement': '-8.4473', 'percent_pruned': '25.9251'}
# {'target_domain': 'cartoon', 'warmup_model': 'd:\\Haseeb\\pruning_sproj\\warmup_cartoon.pth', 'pruned_model': 'd:\\Haseeb\\pruning_sproj\\pruned_cartoon.pth', 'mask_file': 'd:\\Haseeb\\pruning_sproj\\mask_cartoon.pth', 'best_warmup_acc': '73.1655', 'final_pruned_acc': '69.5819', 'improvement': '-3.5836', 'percent_pruned': '25.9251'}
# {'target_domain': 'photo', 'warmup_model': 'd:\\Haseeb\\pruning_sproj\\warmup_photo.pth', 'pruned_model': 'd:\\Haseeb\\pruning_sproj\\pruned_photo.pth', 'mask_file': 'd:\\Haseeb\\pruning_sproj\\mask_photo.pth', 'best_warmup_acc': '94.0120', 'final_pruned_acc': '92.8743', 'improvement': '-1.1377', 'percent_pruned': '25.9251'}
# {'target_domain': 'sketch', 'warmup_model': 'd:\\Haseeb\\pruning_sproj\\warmup_sketch.pth', 'pruned_model': 'd:\\Haseeb\\pruning_sproj\\pruned_sketch.pth', 'mask_file': 'd:\\Haseeb\\pruning_sproj\\mask_sketch.pth', 'best_warmup_acc': '64.9529', 'final_pruned_acc': '67.8035', 'improvement': '2.8506', 'percent_pruned': '25.9251'}
#
# CSV saved at: d:\Haseeb\pruning_sproj\pacs_pruning_results.csv

# %%
import os
import csv
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models

from dataset import get_pacs_dataloaders
from utils import *
from pruning import iterative_pruning

ALL_DOMAINS = ['art_painting', 'cartoon', 'photo', 'sketch']
BATCH_SIZE = 256
NUM_WORKERS = 2
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

PRUNE_RATES = [0.10, 0.10, 0.10]
FINETUNE_EPOCHS = 5
FINETUNE_LR = 1e-4
ALPHA = 1.0


# CSV output
CSV_PATH = "pacs_pruning_results.csv"
CSV_FIELDS = [
    "target_domain",
    "warmup_model",
    "pruned_model",
    "mask_file",
    "best_warmup_acc",
    "final_pruned_acc",
    "improvement",
    "percent_pruned"   # percent of parameters removed (sparsity)
]


def ensure_csv_header(path, fields):
    if not os.path.exists(path):
        with open(path, "w", newline="") as f:
            writer = csv.DictWriter(f, fieldnames=fields)
            writer.writeheader()


def append_result_to_csv(path, row, fields):
    with open(path, "a", newline="") as f:
        writer = csv.DictWriter(f, fieldnames=fields)
        writer.writerow(row)


def compute_percent_pruned(mask):
    """
    Given `mask` (assumed to be a state-dict-like mapping of tensors with 0/1),
    compute percentage of parameters that are zero (pruned).
    """
    total = 0
    zeros = 0
    for k, v in mask.items():
        if not isinstance(v, torch.Tensor):
            try:
                v = torch.tensor(v)
            except Exception:
                continue
        total += v.numel()
        zeros += int((v == 0).sum().item())
    if total == 0:
        return 0.0
    percent_pruned = 100.0 * zeros / total
    return percent_pruned


def run_for_target_domain(TARGET_DOMAIN):
    print("\n" + "=" * 70)
    print(f"RUNNING PIPELINE FOR TARGET DOMAIN: {TARGET_DOMAIN}")
    print("=" * 70 + "\n")

    SOURCE_DOMAINS = [d for d in ALL_DOMAINS if d != TARGET_DOMAIN]
    WARMUP_MODEL_PATH = f"warmup_{TARGET_DOMAIN}.pth"
    PRUNED_MODEL_PATH = f"pruned_{TARGET_DOMAIN}.pth"
    PRUNED_MASK_PATH = f"mask_{TARGET_DOMAIN}.pth"

    # ---------- DATALOADERS ----------
    source_loader_combined, target_loader, class_to_idx = get_pacs_dataloaders(
        data_dir=DATA_DIR,
        source_domains=SOURCE_DOMAINS,
        target_domain=TARGET_DOMAIN,
        batch_size=BATCH_SIZE,
        num_workers=NUM_WORKERS,
        combine_sources=True
    )
    num_classes = len(class_to_idx)

    # ---------- WARMUP ----------
    best_warmup_acc = 0.0
    if os.path.exists(WARMUP_MODEL_PATH):
        print(f"Found existing warmup checkpoint: {WARMUP_MODEL_PATH}. Loading.")
        model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
        model.fc = nn.Linear(model.fc.in_features, num_classes)
        model.load_state_dict(torch.load(WARMUP_MODEL_PATH, map_location=DEVICE))
        model.to(DEVICE)
        # optional: evaluate loaded model to populate best_warmup_acc
        _, best_warmup_acc = evaluate(model, target_loader, DEVICE)
        print(f"  Warmup loaded eval -> {best_warmup_acc:.2f}%")
    else:
        print("No warmup checkpoint found. Running warmup training.")
        model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
        model.fc = nn.Linear(model.fc.in_features, num_classes)
        model.to(DEVICE)
        optimizer = optim.Adam(model.parameters(), lr=1e-4)
        WARMUP_EPOCHS = 5
        for epoch in range(WARMUP_EPOCHS):
            train_vanilla(model, source_loader_combined, optimizer, DEVICE, epoch)
            _, val_acc = evaluate(model, target_loader, DEVICE)
            print(f"  Warmup Epoch {epoch+1}: Target Accuracy = {val_acc:.2f}%")
            if val_acc > best_warmup_acc:
                best_warmup_acc = val_acc
                torch.save(model.state_dict(), WARMUP_MODEL_PATH)
                print(f"    Saved new best warmup ({best_warmup_acc:.2f}%).")

    # ---------- PRUNING ----------
    print("\nStarting iterative pruning...")
    source_loaders_list, target_loader, _ = get_pacs_dataloaders(
        data_dir=DATA_DIR,
        source_domains=SOURCE_DOMAINS,
        target_domain=TARGET_DOMAIN,
        batch_size=BATCH_SIZE,
        num_workers=NUM_WORKERS,
        combine_sources=False
    )

    pruning_model = models.resnet18()
    pruning_model.fc = nn.Linear(pruning_model.fc.in_features, num_classes)
    pruning_model.load_state_dict(torch.load(WARMUP_MODEL_PATH, map_location=DEVICE))
    pruning_model.to(DEVICE)

    final_model, final_mask = iterative_pruning(
        model=pruning_model,
        source_loaders_list=source_loaders_list,
        target_loader=target_loader,
        device=DEVICE,
        prune_rates=PRUNE_RATES,
        retrain_epochs=FINETUNE_EPOCHS,
        lr=FINETUNE_LR,
        alpha=ALPHA,
        batch_size=BATCH_SIZE,
        num_workers=NUM_WORKERS,
        SFT=True,
        importance_type="taylor"
    )

    # ---------- FINAL EVAL ----------
    apply_mask(final_model, final_mask)
    _, final_acc = evaluate(final_model, target_loader, DEVICE, mask=final_mask)
    percent_pruned = compute_percent_pruned(final_mask)

    print("\n--- Summary for", TARGET_DOMAIN, "---")
    print(f"Warmup best acc: {best_warmup_acc:.2f}%")
    print(f"Final pruned acc: {final_acc:.2f}%")
    print(f"Improvement: {final_acc - best_warmup_acc:+.2f}%")
    print(f"Percent pruned (zeros in mask): {percent_pruned:.2f}%")

    # Save artifacts
    torch.save(final_model.state_dict(), PRUNED_MODEL_PATH)
    torch.save(final_mask, PRUNED_MASK_PATH)

    # Append result row to CSV
    row = {
        "target_domain": TARGET_DOMAIN,
        "warmup_model": os.path.abspath(WARMUP_MODEL_PATH),
        "pruned_model": os.path.abspath(PRUNED_MODEL_PATH),
        "mask_file": os.path.abspath(PRUNED_MASK_PATH),
        "best_warmup_acc": f"{best_warmup_acc:.4f}",
        "final_pruned_acc": f"{final_acc:.4f}",
        "improvement": f"{(final_acc - best_warmup_acc):.4f}",
        "percent_pruned": f"{percent_pruned:.4f}"
    }
    append_result_to_csv(CSV_PATH, row, CSV_FIELDS)
    print(f"Results appended to {CSV_PATH}")

    return row


if __name__ == "__main__":
    ensure_csv_header(CSV_PATH, CSV_FIELDS)

    all_results = []
    for domain in ALL_DOMAINS:
        try:
            res = run_for_target_domain(domain)
            all_results.append(res)
        except Exception as e:
            print(f"ERROR while processing {domain}: {e}")
            # continue with next domain
            continue

    # Print final table (simple)
    print("\nALL RUNS COMPLETE. Summary rows:")
    for r in all_results:
        print(r)
    print(f"\nCSV saved at: {os.path.abspath(CSV_PATH)}")
# Out:
# ======================================================================
# RUNNING PIPELINE FOR TARGET DOMAIN: art_painting
# ======================================================================
#
# Creating source datasets for: ['cartoon', 'photo', 'sketch']
#   - Domain 'cartoon' (ID 0) loaded with 2344 images.
#   - Domain 'photo' (ID 1) loaded with 1670 images.
#   - Domain 'sketch' (ID 2) loaded with 3929 images.
# Combined source dataloader created with 7943 total images.
# Creating target dataloader for: art_painting
#   - Domain 'art_painting' loaded with 2048 images.
# Found existing warmup checkpoint: warmup_art_painting.pth. Loading.
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Warmup loaded eval -> 74.37%
#
# Starting iterative pruning...
# Creating source datasets for: ['cartoon', 'photo', 'sketch']
#   - Domain 'cartoon' (ID 0) loaded with 2344 images.
#   - Domain 'photo' (ID 1) loaded with 1670 images.
#   - Domain 'sketch' (ID 2) loaded with 3929 images.
# Created 3 separate source dataloaders.
# Creating target dataloader for: art_painting
#   - Domain 'art_painting' loaded with 2048 images.
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
# Initial Baseline Target Accuracy: 74.37%
#
# --- Pruning Iteration 1/3 with base rate 0.1 ---
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 51/512 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Train2 (Normal):   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 69.53%
#
# Retraining Epoch 2/5
# Epoch 2 Train2 (Normal):   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 66.21%
#
# Retraining Epoch 3/5
# Epoch 3 Train2 (Normal):   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 70.02%
#
# Retraining Epoch 4/5
# Epoch 4 Train2 (Normal):   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 71.48%
#
# Retraining Epoch 5/5
# Epoch 5 Train2 (Normal):   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 67.38%
# Iteration 1 | Best Accuracy in this round: 71.48%
#
# --- Pruning Iteration 2/3 with base rate 0.1 ---
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 46/461 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Train2 (Normal):   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 72.02%
#
# Retraining Epoch 2/5
# Epoch 2 Train2 (Normal):   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 68.36%
#
# Retraining Epoch 3/5
# Epoch 3 Train2 (Normal):   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 72.56%
#
# Retraining Epoch 4/5
# Epoch 4 Train2 (Normal):   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 73.24%
#
# Retraining Epoch 5/5
# Epoch 5 Train2 (Normal):   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 74.56%
# Iteration 2 | Best Accuracy in this round: 74.56%
#
# --- Pruning Iteration 3/3 with base rate 0.1 ---
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 41/415 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Train2 (Normal):   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 68.99%
#
# Retraining Epoch 2/5
# Epoch 2 Train2 (Normal):   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 68.21%
#
# Retraining Epoch 3/5
# Epoch 3 Train2 (Normal):   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 71.24%
#
# Retraining Epoch 4/5
# Epoch 4 Train2 (Normal):   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 70.75%
#
# Retraining Epoch 5/5
# Epoch 5 Train2 (Normal):   0%|          | 0/32 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 69.04%
# Iteration 3 | Best Accuracy in this round: 71.24%
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
# --- Summary for art_painting ---
# Warmup best acc: 74.37%
# Final pruned acc: 71.24%
# Improvement: -3.12%
# Percent pruned (zeros in mask): 25.93%
# Results appended to pacs_pruning_results.csv
#
# ======================================================================
# RUNNING PIPELINE FOR TARGET DOMAIN: cartoon
# ======================================================================
#
# Creating source datasets for: ['art_painting', 'photo', 'sketch']
#   - Domain 'art_painting' (ID 0) loaded with 2048 images.
#   - Domain 'photo' (ID 1) loaded with 1670 images.
#   - Domain 'sketch' (ID 2) loaded with 3929 images.
# Combined source dataloader created with 7647 total images.
# Creating target dataloader for: cartoon
#   - Domain 'cartoon' loaded with 2344 images.
# Found existing warmup checkpoint: warmup_cartoon.pth. Loading.
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Warmup loaded eval -> 73.17%
#
# Starting iterative pruning...
# Creating source datasets for: ['art_painting', 'photo', 'sketch']
#   - Domain 'art_painting' (ID 0) loaded with 2048 images.
#   - Domain 'photo' (ID 1) loaded with 1670 images.
#   - Domain 'sketch' (ID 2) loaded with 3929 images.
# Created 3 separate source dataloaders.
# Creating target dataloader for: cartoon
#   - Domain 'cartoon' loaded with 2344 images.
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
# Initial Baseline Target Accuracy: 73.17%
#
# --- Pruning Iteration 1/3 with base rate 0.1 ---
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 51/512 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Train2 (Normal):   0%|          | 0/30 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 69.24%
#
# Retraining Epoch 2/5
# Epoch 2 Train2 (Normal):   0%|          | 0/30 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 75.09%
#
# Retraining Epoch 3/5
# Epoch 3 Train2 (Normal):   0%|          | 0/30 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 72.99%
#
# Retraining Epoch 4/5
# Epoch 4 Train2 (Normal):   0%|          | 0/30 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 72.53%
#
# Retraining Epoch 5/5
# Epoch 5 Train2 (Normal):   0%|          | 0/30 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 71.59%
# Iteration 1 | Best Accuracy in this round: 75.09%
#
# --- Pruning Iteration 2/3 with base rate 0.1 ---
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 46/461 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Train2 (Normal):   0%|          | 0/30 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 65.61%
#
# Retraining Epoch 2/5
# Epoch 2 Train2 (Normal):   0%|          | 0/30 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 73.04%
#
# Retraining Epoch 3/5
# Epoch 3 Train2 (Normal):   0%|          | 0/30 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 72.53%
#
# Retraining Epoch 4/5
# Epoch 4 Train2 (Normal):   0%|          | 0/30 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 69.37%
#
# Retraining Epoch 5/5
# Epoch 5 Train2 (Normal):   0%|          | 0/30 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 73.12%
# Iteration 2 | Best Accuracy in this round: 73.12%
#
# --- Pruning Iteration 3/3 with base rate 0.1 ---
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 41/415 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Train2 (Normal):   0%|          | 0/30 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 74.53%
#
# Retraining Epoch 2/5
# Epoch 2 Train2 (Normal):   0%|          | 0/30 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 72.99%
#
# Retraining Epoch 3/5
# Epoch 3 Train2 (Normal):   0%|          | 0/30 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 72.82%
#
# Retraining Epoch 4/5
# Epoch 4 Train2 (Normal):   0%|          | 0/30 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 71.46%
#
# Retraining Epoch 5/5
# Epoch 5 Train2 (Normal):   0%|          | 0/30 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 71.08%
# Iteration 3 | Best Accuracy in this round: 74.53%
# Evaluating:   0%|          | 0/5 [00:00<?, ?it/s]
# --- Summary for cartoon ---
# Warmup best acc: 73.17%
# Final pruned acc: 74.53%
# Improvement: +1.37%
# Percent pruned (zeros in mask): 25.93%
# Results appended to pacs_pruning_results.csv
#
# ======================================================================
# RUNNING PIPELINE FOR TARGET DOMAIN: photo
# ======================================================================
#
# Creating source datasets for: ['art_painting', 'cartoon', 'sketch']
#   - Domain 'art_painting' (ID 0) loaded with 2048 images.
#   - Domain 'cartoon' (ID 1) loaded with 2344 images.
#   - Domain 'sketch' (ID 2) loaded with 3929 images.
# Combined source dataloader created with 8321 total images.
# Creating target dataloader for: photo
#   - Domain 'photo' loaded with 1670 images.
# Found existing warmup checkpoint: warmup_photo.pth. Loading.
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Warmup loaded eval -> 94.01%
#
# Starting iterative pruning...
# Creating source datasets for: ['art_painting', 'cartoon', 'sketch']
#   - Domain 'art_painting' (ID 0) loaded with 2048 images.
#   - Domain 'cartoon' (ID 1) loaded with 2344 images.
#   - Domain 'sketch' (ID 2) loaded with 3929 images.
# Created 3 separate source dataloaders.
# Creating target dataloader for: photo
#   - Domain 'photo' loaded with 1670 images.
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
# Initial Baseline Target Accuracy: 94.01%
#
# --- Pruning Iteration 1/3 with base rate 0.1 ---
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 51/512 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Train2 (Normal):   0%|          | 0/33 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 94.19%
#
# Retraining Epoch 2/5
# Epoch 2 Train2 (Normal):   0%|          | 0/33 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 94.13%
#
# Retraining Epoch 3/5
# Epoch 3 Train2 (Normal):   0%|          | 0/33 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 94.31%
#
# Retraining Epoch 4/5
# Epoch 4 Train2 (Normal):   0%|          | 0/33 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 94.13%
#
# Retraining Epoch 5/5
# Epoch 5 Train2 (Normal):   0%|          | 0/33 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 94.07%
# Iteration 1 | Best Accuracy in this round: 94.31%
#
# --- Pruning Iteration 2/3 with base rate 0.1 ---
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 46/461 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Train2 (Normal):   0%|          | 0/33 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 90.18%
#
# Retraining Epoch 2/5
# Epoch 2 Train2 (Normal):   0%|          | 0/33 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 90.00%
#
# Retraining Epoch 3/5
# Epoch 3 Train2 (Normal):   0%|          | 0/33 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 92.46%
#
# Retraining Epoch 4/5
# Epoch 4 Train2 (Normal):   0%|          | 0/33 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 91.80%
#
# Retraining Epoch 5/5
# Epoch 5 Train2 (Normal):   0%|          | 0/33 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 92.63%
# Iteration 2 | Best Accuracy in this round: 92.63%
#
# --- Pruning Iteration 3/3 with base rate 0.1 ---
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 41/415 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Train2 (Normal):   0%|          | 0/33 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 92.51%
#
# Retraining Epoch 2/5
# Epoch 2 Train2 (Normal):   0%|          | 0/33 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 91.80%
#
# Retraining Epoch 3/5
# Epoch 3 Train2 (Normal):   0%|          | 0/33 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 92.10%
#
# Retraining Epoch 4/5
# Epoch 4 Train2 (Normal):   0%|          | 0/33 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 92.22%
#
# Retraining Epoch 5/5
# Epoch 5 Train2 (Normal):   0%|          | 0/33 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 92.40%
# Iteration 3 | Best Accuracy in this round: 92.51%
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
# --- Summary for photo ---
# Warmup best acc: 94.01%
# Final pruned acc: 92.51%
# Improvement: -1.50%
# Percent pruned (zeros in mask): 25.93%
# Results appended to pacs_pruning_results.csv
#
# ======================================================================
# RUNNING PIPELINE FOR TARGET DOMAIN: sketch
# ======================================================================
#
# Creating source datasets for: ['art_painting', 'cartoon', 'photo']
#   - Domain 'art_painting' (ID 0) loaded with 2048 images.
#   - Domain 'cartoon' (ID 1) loaded with 2344 images.
#   - Domain 'photo' (ID 2) loaded with 1670 images.
# Combined source dataloader created with 6062 total images.
# Creating target dataloader for: sketch
#   - Domain 'sketch' loaded with 3929 images.
# Found existing warmup checkpoint: warmup_sketch.pth. Loading.
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Warmup loaded eval -> 64.95%
#
# Starting iterative pruning...
# Creating source datasets for: ['art_painting', 'cartoon', 'photo']
#   - Domain 'art_painting' (ID 0) loaded with 2048 images.
#   - Domain 'cartoon' (ID 1) loaded with 2344 images.
#   - Domain 'photo' (ID 2) loaded with 1670 images.
# Created 3 separate source dataloaders.
# Creating target dataloader for: sketch
#   - Domain 'sketch' loaded with 3929 images.
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
# Initial Baseline Target Accuracy: 64.95%
#
# --- Pruning Iteration 1/3 with base rate 0.1 ---
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/64 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 6/128 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 25/256 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 51/512 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 51/512 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 55.64%
#
# Retraining Epoch 2/5
# Epoch 2 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 58.13%
#
# Retraining Epoch 3/5
# Epoch 3 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 57.39%
#
# Retraining Epoch 4/5
# Epoch 4 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 60.47%
#
# Retraining Epoch 5/5
# Epoch 5 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 59.02%
# Iteration 1 | Best Accuracy in this round: 60.47%
#
# --- Pruning Iteration 2/3 with base rate 0.1 ---
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/63 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 6/122 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 23/231 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 46/461 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 46/461 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 52.74%
#
# Retraining Epoch 2/5
# Epoch 2 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 55.56%
#
# Retraining Epoch 3/5
# Epoch 3 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 56.07%
#
# Retraining Epoch 4/5
# Epoch 4 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 58.06%
#
# Retraining Epoch 5/5
# Epoch 5 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 57.67%
# Iteration 2 | Best Accuracy in this round: 58.06%
#
# --- Pruning Iteration 3/3 with base rate 0.1 ---
#
# Generating mask with base iterative prune rate: 0.1
#   - Layer 'conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.0.conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.0.conv2': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.1.conv1': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer1.1.conv2': Pruning 1/62 active filters (rate 0.025).
#   - Layer 'layer2.0.conv1': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.0.conv2': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.0.downsample.0': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.1.conv1': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer2.1.conv2': Pruning 5/116 active filters (rate 0.050).
#   - Layer 'layer3.0.conv1': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.0.conv2': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.0.downsample.0': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.1.conv1': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer3.1.conv2': Pruning 20/208 active filters (rate 0.100).
#   - Layer 'layer4.0.conv1': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.0.conv2': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.0.downsample.0': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.1.conv1': Pruning 41/415 active filters (rate 0.100).
#   - Layer 'layer4.1.conv2': Pruning 41/415 active filters (rate 0.100).
#
# Retraining Epoch 1/5
# Epoch 1 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 1 Target Accuracy: 64.42%
#
# Retraining Epoch 2/5
# Epoch 2 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 2 Target Accuracy: 62.46%
#
# Retraining Epoch 3/5
# Epoch 3 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 3 Target Accuracy: 60.60%
#
# Retraining Epoch 4/5
# Epoch 4 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 4 Target Accuracy: 58.97%
#
# Retraining Epoch 5/5
# Epoch 5 Train2 (Normal):   0%|          | 0/24 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#   Epoch 5 Target Accuracy: 59.84%
# Iteration 3 | Best Accuracy in this round: 64.42%
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
# --- Summary for sketch ---
# Warmup best acc: 64.95%
# Final pruned acc: 64.42%
# Improvement: -0.53%
# Percent pruned (zeros in mask): 25.93%
# Results appended to pacs_pruning_results.csv
#
# ALL RUNS COMPLETE. Summary rows:
# {'target_domain': 'art_painting', 'warmup_model': 'd:\\Haseeb\\pruning_sproj\\warmup_art_painting.pth', 'pruned_model': 'd:\\Haseeb\\pruning_sproj\\pruned_art_painting.pth', 'mask_file': 'd:\\Haseeb\\pruning_sproj\\mask_art_painting.pth', 'best_warmup_acc': '74.3652', 'final_pruned_acc': '71.2402', 'improvement': '-3.1250', 'percent_pruned': '25.9251'}
# {'target_domain': 'cartoon', 'warmup_model': 'd:\\Haseeb\\pruning_sproj\\warmup_cartoon.pth', 'pruned_model': 'd:\\Haseeb\\pruning_sproj\\pruned_cartoon.pth', 'mask_file': 'd:\\Haseeb\\pruning_sproj\\mask_cartoon.pth', 'best_warmup_acc': '73.1655', 'final_pruned_acc': '74.5307', 'improvement': '1.3652', 'percent_pruned': '25.9251'}
# {'target_domain': 'photo', 'warmup_model': 'd:\\Haseeb\\pruning_sproj\\warmup_photo.pth', 'pruned_model': 'd:\\Haseeb\\pruning_sproj\\pruned_photo.pth', 'mask_file': 'd:\\Haseeb\\pruning_sproj\\mask_photo.pth', 'best_warmup_acc': '94.0120', 'final_pruned_acc': '92.5150', 'improvement': '-1.4970', 'percent_pruned': '25.9251'}
# {'target_domain': 'sketch', 'warmup_model': 'd:\\Haseeb\\pruning_sproj\\warmup_sketch.pth', 'pruned_model': 'd:\\Haseeb\\pruning_sproj\\pruned_sketch.pth', 'mask_file': 'd:\\Haseeb\\pruning_sproj\\mask_sketch.pth', 'best_warmup_acc': '64.9529', 'final_pruned_acc': '64.4184', 'improvement': '-0.5345', 'percent_pruned': '25.9251'}
#
# CSV saved at: d:\Haseeb\pruning_sproj\pacs_pruning_results.csv
